# %% [markdown]
# # Explore here

# %%
# Your code here
import pandas as pd

data = pd.read_csv("https://raw.githubusercontent.com/4GeeksAcademy/regularized-linear-regression-project-tutorial/main/demographic_health_data.csv")
data

#
# Out:
#        fips  TOT_POP    0-9  0-9 y/o % of total pop  19-Oct  \
# 0      1001    55601   6787               12.206615    7637
# 1      1003   218022  24757               11.355276   26913
# 2      1005    24881   2732               10.980266    2960
# 3      1007    22400   2456               10.964286    2596
# 4      1009    57840   7095               12.266598    7570
# ...     ...      ...    ...                     ...     ...
# 3135  56037    43051   6104               14.178532    6326
# 3136  56039    23081   2384               10.328842    2185
# 3137  56041    20299   3121               15.375142    3205
# 3138  56043     7885    858               10.881420    1113
# 3139  56045     6967    780               11.195637     779
#
#       10-19 y/o % of total pop  20-29  20-29 y/o % of total pop  30-39  \
# 0                    13.735364   6878                 12.370281   7089
# 1                    12.344167  23579                 10.814964  25213
# ...

# %% [markdown]
# Explore the data

# %%
# see the shape
# see if numerical or categorical values
# factorise (put categorical values into numerical)
# put everything into scale to then use the models

data.shape
# Out:
# (3140, 108)

# %%
data.info()
# two columns are not numerical, if we want to use the categorical ones we need to convert them (that's why we need to see which ones are which)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3140 entries, 0 to 3139
# Columns: 108 entries, fips to Urban_rural_code
# dtypes: float64(61), int64(45), object(2)
# memory usage: 2.6+ MB

# %%
# to check which ones are categorical and which ones numerical
# make a loop to insert integer columns and object columns in two different lists and print them to see them

# or use d.type

# %%
data.isnull().sum()
# each column has zero null values
# Out:
# fips                      0
# TOT_POP                   0
# 0-9                       0
# 0-9 y/o % of total pop    0
# 19-Oct                    0
#                          ..
# CKD_prevalence            0
# CKD_Lower 95% CI          0
# CKD_Upper 95% CI          0
# CKD_number                0
# Urban_rural_code          0
# Length: 108, dtype: int64

# %%
pd.set_option('display.max_columns', None) # global function, works even when not associated with data, tells pd to show all columns no matter what
data.head() # to see the columns
# Out:
#    fips  TOT_POP    0-9  0-9 y/o % of total pop  19-Oct  \
# 0  1001    55601   6787               12.206615    7637
# 1  1003   218022  24757               11.355276   26913
# 2  1005    24881   2732               10.980266    2960
# 3  1007    22400   2456               10.964286    2596
# 4  1009    57840   7095               12.266598    7570
#
#    10-19 y/o % of total pop  20-29  20-29 y/o % of total pop  30-39  \
# 0                 13.735364   6878                 12.370281   7089
# 1                 12.344167  23579                 10.814964  25213
# 2                 11.896628   3268                 13.134520   3201
# 3                 11.589286   3029                 13.522321   3113
# 4                 13.087828   6742                 11.656293   6884
#
#    30-39 y/o % of total pop  40-49  40-49 y/o % of total pop  50-59  \
# 0                 12.749771   7582                 13.636445   7738
# 1                 11.564429  27338                 12.539102  29986
# ...

# %%
# get info about the people, then try to predict the number of health services
# e.g. for the sociological data try to predict  diabetes (column) (maybe they have higher probability of diabetes when they are 40 e.g.)

X = data.["Obesity_number"]
